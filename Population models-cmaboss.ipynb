# %%
import cmaboss, pandas, maboss, json, collections
import matplotlib.pyplot as plt
import numpy as np
# Out:
# <script type="text/javascript" id="colomoto-setup-7862343" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# ...

# %% [markdown]
# ### MaBoSS

# %%
net = cmaboss.MaBoSSNet("tuto/maboss/Fork.bnd")

# %%
cfg = cmaboss.MaBoSSCfg(net, "tuto/maboss/Fork.cfg")

# %%
sim = cmaboss.MaBoSSSim(network="tuto/maboss/Fork.bnd", config="tuto/maboss/Fork.cfg")

# %%
sim = maboss.load("tuto/maboss/Fork.bnd", "tuto/maboss/Fork.cfg", cmaboss=True)

# %%
res = sim.run()
res.plot_piechart()

# %%
res.plot_trajectory()

# %%
sim.print_bnd()
# Out:
# node A {
#   logic = A;
#   rate_up = (@logic ? 1 : 0);
#   rate_down = 0;
# }
#
# node C {
#   logic = (A AND NOT B);
#   rate_up = (@logic ? 1 : 0);
#   rate_down = 0;
# }
#
# node B {
#   logic = (A AND NOT C);
#   rate_up = (@logic ? 1 : 0);
#   rate_down = 0;
# }

# %%
sim.print_cfg()
# Out:
# time_tick = 0.01;
# max_time = 5;
# sample_count = 100000;
# discrete_time = 0;
# use_physrandgen = 0;
# seed_pseudorandom = 100;
# display_traj = 0;
# statdist_traj_count = 0;
# statdist_cluster_threshold = 1;
# thread_count = 6;
# statdist_similarity_cache_max_size = 20000;
#
# A.is_internal = 0;
# C.is_internal = 0;
# B.is_internal = 0;
#
# A.refstate = -1;
# C.refstate = -1;
# B.refstate = -1;
#
# A.istate = 1;
# B.istate = 0;
# C.istate = 0;

# %%
sim_newistate = sim.copy()
sim_newistate.network.set_istate('B', 0.1)
sim_newistate.print_cfg()
# Out:
# time_tick = 0.01;
# max_time = 5;
# sample_count = 100000;
# discrete_time = 0;
# use_physrandgen = 0;
# seed_pseudorandom = 100;
# display_traj = 0;
# statdist_traj_count = 0;
# statdist_cluster_threshold = 1;
# thread_count = 6;
# statdist_similarity_cache_max_size = 20000;
#
# A.is_internal = 0;
# B.is_internal = 0;
# C.is_internal = 0;
#
# A.refstate = -1;
# B.refstate = -1;
# C.refstate = -1;
#
# A.istate = 1;
# C.istate = 0;
# [B].istate = 0.9 [0], 0.1 [1];

# %%
sim_newistate.network.set_istate('B', [1,3])
sim_newistate.print_cfg()
# Out:
# time_tick = 0.01;
# max_time = 5;
# sample_count = 100000;
# discrete_time = 0;
# use_physrandgen = 0;
# seed_pseudorandom = 100;
# display_traj = 0;
# statdist_traj_count = 0;
# statdist_cluster_threshold = 1;
# thread_count = 6;
# statdist_similarity_cache_max_size = 20000;
#
# A.is_internal = 0;
# B.is_internal = 0;
# C.is_internal = 0;
#
# A.refstate = -1;
# B.refstate = -1;
# C.refstate = -1;
#
# A.istate = 1;
# C.istate = 0;
# [B].istate = 0.25 [0], 0.75 [1];

# %%
sim_newistate.network.set_istate(['B', 'C'], {(0,0): 0.4, (1,1): 0.6})
sim_newistate.print_cfg()
# Out:
# time_tick = 0.01;
# max_time = 5;
# sample_count = 100000;
# discrete_time = 0;
# use_physrandgen = 0;
# seed_pseudorandom = 100;
# display_traj = 0;
# statdist_traj_count = 0;
# statdist_cluster_threshold = 1;
# thread_count = 6;
# statdist_similarity_cache_max_size = 20000;
#
# A.is_internal = 0;
# B.is_internal = 0;
# C.is_internal = 0;
#
# A.refstate = -1;
# B.refstate = -1;
# C.refstate = -1;
#
# A.istate = 1;
# [B, C].istate = 0.4 [0, 0], 0.6 [1, 1];

# %%
sim_newistate.network.set_istate('B', 0.1)
sim_newistate.print_cfg()
# Out:
# time_tick = 0.01;
# max_time = 5;
# sample_count = 100000;
# discrete_time = 0;
# use_physrandgen = 0;
# seed_pseudorandom = 100;
# display_traj = 0;
# statdist_traj_count = 0;
# statdist_cluster_threshold = 1;
# thread_count = 6;
# statdist_similarity_cache_max_size = 20000;
#
# A.is_internal = 0;
# B.is_internal = 0;
# C.is_internal = 0;
#
# A.refstate = -1;
# B.refstate = -1;
# C.refstate = -1;
#
# A.istate = 1;
# [C].istate = 0.4 [0], 0.6 [1];
# [B].istate = 0.9 [0], 0.1 [1];

# %%
sim_newistate.network.set_istate(['A', 'C'], {(0,0): 0.7, (1,1): 0.3})
sim_newistate.print_cfg()
# Out:
# time_tick = 0.01;
# max_time = 5;
# sample_count = 100000;
# discrete_time = 0;
# use_physrandgen = 0;
# seed_pseudorandom = 100;
# display_traj = 0;
# statdist_traj_count = 0;
# statdist_cluster_threshold = 1;
# thread_count = 6;
# statdist_similarity_cache_max_size = 20000;
#
# A.is_internal = 0;
# B.is_internal = 0;
# C.is_internal = 0;
#
# A.refstate = -1;
# B.refstate = -1;
# C.refstate = -1;
#
# [B].istate = 0.9 [0], 0.1 [1];
# [A, C].istate = 0.7 [0, 0], 0.3 [1, 1];

# %%
sim_newistate.network.set_istate('C', 0.5)
sim_newistate.print_cfg()
# Out:
# time_tick = 0.01;
# max_time = 5;
# sample_count = 100000;
# discrete_time = 0;
# use_physrandgen = 0;
# seed_pseudorandom = 100;
# display_traj = 0;
# statdist_traj_count = 0;
# statdist_cluster_threshold = 1;
# thread_count = 6;
# statdist_similarity_cache_max_size = 20000;
#
# A.is_internal = 0;
# B.is_internal = 0;
# C.is_internal = 0;
#
# A.refstate = -1;
# B.refstate = -1;
# C.refstate = -1;
#
# [B].istate = 0.9 [0], 0.1 [1];
# [A].istate = 0.7 [0], 0.3 [1];

# %%
sim_newistate.network.set_istate(['A', 'B', 'C'], {(1,0,0): 1.0})
sim_newistate.print_cfg()
# Out:
# time_tick = 0.01;
# max_time = 5;
# sample_count = 100000;
# discrete_time = 0;
# use_physrandgen = 0;
# seed_pseudorandom = 100;
# display_traj = 0;
# statdist_traj_count = 0;
# statdist_cluster_threshold = 1;
# thread_count = 6;
# statdist_similarity_cache_max_size = 20000;
#
# A.is_internal = 0;
# B.is_internal = 0;
# C.is_internal = 0;
#
# A.refstate = -1;
# B.refstate = -1;
# C.refstate = -1;
#
# [A, B, C].istate = 1 [1, 0, 0];

# %% [markdown]
# ### PopMaBoSS

# %%
pop_sim = maboss.PopSimulation(maboss_model=sim)

# %%
pop_res = pop_sim.run()

# %%
pop_res.plot_last_state_dist()

# %%
pop_res.get_states_probtraj().plot.area(legend=True, xlim=[0,5], ylim=[0,1])
# Out:
# <Axes: >

# %% [markdown]
# ### Adding division rule

# %%
pop_sim.network.get_division_rules()
# Out:
# {}

# %%
pop_sim.network.add_division_rule("A & !(B|C) ? 1.0 : 0.0", {}, {'A': 1, 'B': 0, 'C': 0})

# %%
pop_sim.network.get_division_rules()
# Out:
# {0: ('((A AND NOT ((B OR C))) ? 1 : 0)', {}, {'B': '0', 'C': '0', 'A': '1'})}

# %%
pop_sim.network.add_division_rule("0.2", {}, {})

# %%
pop_sim.network.get_division_rules()
# Out:
# {0: ('((A AND NOT ((B OR C))) ? 1 : 0)', {}, {'B': '0', 'C': '0', 'A': '1'}),
#  1: ('0.2', {}, {})}

# %%
pop_sim.print_bnd()
# Out:
# node A {
#   logic = A;
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# node B {
#   logic = ((A AND NOT C));
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# node C {
#   logic = ((A AND NOT B));
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# division {
#   rate=((A AND NOT ((B OR C))) ? 1 : 0);
#   B.DAUGHTER2 = 0;
#   C.DAUGHTER2 = 0;
#   A.DAUGHTER2 = 1;
# }
#
# division {
#   rate=0.2;
# }

# %%
pop_sim.network.remove_division_rule(1)

# %%
pop_sim.network.get_division_rules()
# Out:
# {0: ('((A AND NOT ((B OR C))) ? 1 : 0)', {}, {'B': '0', 'C': '0', 'A': '1'})}

# %%
pop_sim.print_bnd()
# Out:
# node A {
#   logic = A;
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# node B {
#   logic = ((A AND NOT C));
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# node C {
#   logic = ((A AND NOT B));
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# division {
#   rate=((A AND NOT ((B OR C))) ? 1 : 0);
#   B.DAUGHTER2 = 0;
#   C.DAUGHTER2 = 0;
#   A.DAUGHTER2 = 1;
# }

# %%
res_sim = pop_sim.run()

# %%
res_sim.get_simple_states_popsize().plot.area()
# Out:
# <Axes: >

# %%
res_sim.get_states_probtraj().plot.area(legend=False)
# Out:
# <Axes: >

# %%
res_sim.get_last_state_dist(networkstate='A -- B').plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### Adding death rate

# %%
pop_sim.network.get_death_rate()

# %%
pop_sim.network.set_death_rate("0.5/#cell()")

# %%
pop_sim.network.get_death_rate()
# Out:
# '(0.5 / #cell(1))'

# %%
pop_sim.print_bnd()
# Out:
# node A {
#   logic = A;
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# node B {
#   logic = ((A AND NOT C));
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# node C {
#   logic = ((A AND NOT B));
#   rate_up = ((@logic ? 1 : 0));
#   rate_down = 0;
# }
#
# death {
#   rate = (0.5 / #cell(1));
# }
#
# division {
#   rate=((A AND NOT ((B OR C))) ? 1 : 0);
#   B.DAUGHTER2 = 0;
#   C.DAUGHTER2 = 0;
#   A.DAUGHTER2 = 1;
# }

# %%
pop_sim.network.set_death_rate()

# %%
pop_sim.param['max_time'] = 10
res_sim = pop_sim.run()

# %%
res_sim.get_simple_states_popsize().plot.area()
# Out:
# <Axes: >

# %%
res_sim.get_states_probtraj().plot.area(legend=False)
# Out:
# <Axes: >

# %%
res_sim.get_last_state_dist(networkstate='A -- B').plot.bar()
# Out:
# <Axes: >

# %%
sim = maboss.PopSimulation("tuto/popmaboss/Fork.bnd", "tuto/popmaboss/Fork.cfg")

# %%
sim.network.get_division_rules()
# Out:
# {0: ('((A AND NOT ((B OR C))) ? 1 : 0)', {}, {})}

# %%
# print(sim.network)

# %%
print(sim.network['A'].get_logic())
# Out:
# None

# %%
sim.network['A'].set_rate(1, 0)

# %%
sim.network['A'].get_rate_up()
# Out:
# '1'

# %%
sim.network['A'].get_rate_down()
# Out:
# '0'

# %%
print(sim.network['B'].get_logic())
# Out:
# (A AND NOT C)

# %%
sim.print_bnd()
# Out:
# node A {
#   rate_up = 1;
#   rate_down = 0;
# }
#
# node C {
#   logic = (A AND NOT B);
#   rate_up = (@logic ? 1 : 0);
#   rate_down = 0;
# }
#
# node B {
#   logic = (A AND NOT C);
#   rate_up = (@logic ? 1 : 0);
#   rate_down = 0;
# }
#
# division {
#   rate=((A AND NOT ((B OR C))) ? 1 : 0);
# }

# %%
sim.network['B'].set_rate(1.0, 0.0)

# %%
sim.network['B'].get_rate_up()
# Out:
# '(@logic ? 1 : 0)'

# %%
sim.network['B'].get_rate_down()
# Out:
# '(@logic ? 0 : 0)'

# %%
sim.param.items()
# Out:
# [('time_tick', 0.1),
#  ('max_time', 10.0),
#  ('sample_count', 100000),
#  ('init_pop', 3),
#  ('discrete_time', False),
#  ('use_physrandgen', False),
#  ('use_glibcrandgen', False),
#  ('use_mtrandgen', False),
#  ('seed_pseudorandom', 100),
#  ('display_traj', 0),
#  ('statdist_traj_count', 0),
#  ('statdist_cluster_threshold', 1.0),
#  ('thread_count', 6),
#  ('statdist_similarity_cache_max_size', 20000),
#  ('init_pop', 3),
#  ('$DivRate', 0.1)]

# %%
#sim.network['A'].set_rate("$u_A", "$d_A")

# %%
sim.param.items()
# Out:
# [('time_tick', 0.1),
#  ('max_time', 10.0),
#  ('sample_count', 100000),
#  ('init_pop', 3),
#  ('discrete_time', False),
#  ('use_physrandgen', False),
#  ('use_glibcrandgen', False),
#  ('use_mtrandgen', False),
#  ('seed_pseudorandom', 100),
#  ('display_traj', 0),
#  ('statdist_traj_count', 0),
#  ('statdist_cluster_threshold', 1.0),
#  ('thread_count', 6),
#  ('statdist_similarity_cache_max_size', 20000),
#  ('init_pop', 3),
#  ('$DivRate', 0.1)]

# %%
sim.param["$u_B"] = 1.0
sim.param["$d_B"] = 1.0

# %%
sim.param.items()
# Out:
# [('time_tick', 0.1),
#  ('max_time', 10.0),
#  ('sample_count', 100000),
#  ('init_pop', 3),
#  ('discrete_time', False),
#  ('use_physrandgen', False),
#  ('use_glibcrandgen', False),
#  ('use_mtrandgen', False),
#  ('seed_pseudorandom', 100),
#  ('display_traj', 0),
#  ('statdist_traj_count', 0),
#  ('statdist_cluster_threshold', 1.0),
#  ('thread_count', 6),
#  ('statdist_similarity_cache_max_size', 20000),
#  ('init_pop', 3),
#  ('$DivRate', 0.1),
#  ('$d_B', 1.0),
#  ('$u_B', 1.0)]

# %%
sim.network['B'].set_rate("$u_B", "$d_B")

# %%
sim.print_bnd()
# Out:
# node A {
#   rate_up = 1;
#   rate_down = 0;
# }
#
# node C {
#   logic = (A AND NOT B);
#   rate_up = (@logic ? 1 : 0);
#   rate_down = 0;
# }
#
# node B {
#   logic = (A AND NOT C);
#   rate_up = (@logic ? $u_B : 0);
#   rate_down = (@logic ? 0 : $d_B);
# }
#
# division {
#   rate=((A AND NOT ((B OR C))) ? 1 : 0);
# }

# %%
sim.network['B']

# %%
type(sim.network)
# Out:
# cmaboss.cPopMaBoSSNetworkObject
